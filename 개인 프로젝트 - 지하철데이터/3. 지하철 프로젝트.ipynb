# %%
import csv
data = csv.reader(open('201806subway.csv'))
next(data)
next(data)
i = int(input('몇시가 궁금하신가요?'))-4
max_person = 0
max_station = ''
for row in data : 
    if(int(max_person) < int(row[2+(i*2)])):
        max_person = row[2+(i*2)]
        max_station = row[1]+'('+ row[0] +')'
print(max_station, max_person)
# Out:
# 몇시가 궁금하신가요?10
# 신림(2호선) 111845

# %%
import csv
data = csv.reader(open('201806subway.csv'))
next(data)
next(data)

max_person1 = [0] * 24
max_station1 = [''] * 24

max_person2 = [0] * 24
max_station2 = [''] * 24
for row in data :
    for i in range(24):
        if int(max_person1[i]) < int(row[2+(i*2)]) :
            max_person1[i] = row[2+(i*2)]
            max_station1[i] = row[1] + '/' + str(i + 4) #+'('+ row[0]+')'
        if int(max_person2[i]) < int(row[3 + (i * 2)]):
            max_person2[i] = row[3 + (i * 2)]
            max_station2[i] = row[1] + '/' + str(i + 4)  # +'('+ row[0]+')'

for i in range(24):
    print(i+4,'시(승차): ', max_station1[i],'/',max_person1[i])
    print(i + 4,'시(하차): ', max_station2[i], '/', max_person2[i])

import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np
plt.rc('font', family='AppleGothic')
cnt = np.arange(24)
# plt.subplot(121)
plt.figure(dpi=150)
plt.title('2018년 6월 서울시 지하철 시간대별 최다 승차역')
plt.plot(cnt, max_person1,'r')
plt.xticks(cnt, max_station1,rotation='vertical')
plt.ylim(ymax=450000)
plt.savefig('2018년6월최다승차역.png')
plt.show()
plt.figure(dpi=150)
# plt.subplot(122)
plt.title('2018년 6월 서울시 지하철 시간대별 최다 하차역')
plt.plot(cnt, max_person2,'b')
plt.xticks(cnt, max_station2,rotation='vertical')
plt.ylim(ymax=450000)
plt.savefig('2018년6월최다하차역.png')
plt.show()
# Out:
# 4 시(승차):  구로/4 / 11061
# 4 시(하차):  창동/4 / 74
# 5 시(승차):  구로디지털단지/5 / 48323
# 5 시(하차):  강남/5 / 12198
# 6 시(승차):  신림/6 / 85930
# 6 시(하차):  강남/6 / 57148
# 7 시(승차):  신림/7 / 231778
# 7 시(하차):  강남/7 / 177670
# 8 시(승차):  신림/8 / 331650
# 8 시(하차):  가산디지털단지/8 / 379854
# 9 시(승차):  신림/9 / 199388
# 9 시(하차):  강남/9 / 346065
# 10 시(승차):  신림/10 / 111845
# 10 시(하차):  강남/10 / 180339
# 11 시(승차):  잠실(송파구청)/11 / 101612
# 11 시(하차):  강남/11 / 150954
# 12 시(승차):  잠실(송파구청)/12 / 111943
# 12 시(하차):  강남/12 / 153808
# 13 시(승차):  강남/13 / 144073
# 13 시(하차):  강남/13 / 182199
# 14 시(승차):  강남/14 / 147431
# 14 시(하차):  홍대입구/14 / 168992
# 15 시(승차):  강남/15 / 177025
# 15 시(하차):  홍대입구/15 / 170229
# 16 시(승차):  강남/16 / 199666
# 16 시(하차):  홍대입구/16 / 181416
# 17 시(승차):  강남/17 / 251332
# 17 시(하차):  홍대입구/17 / 209208
# 18 시(승차):  강남/18 / 382504
# 18 시(하차):  홍대입구/18 / 264957
# 19 시(승차):  강남/19 / 264366
# 19 시(하차):  신림/19 / 257860
# 20 시(승차):  강남/20 / 215243
# 20 시(하차):  신림/20 / 165650
# 21 시(승차):  강남/21 / 258259
# 21 시(하차):  신림/21 / 162194
# 22 시(승차):  강남/22 / 280688
# 22 시(하차):  신림/22 / 165151
# 23 시(승차):  홍대입구/23 / 140057
# 23 시(하차):  신림/23 / 116417
# 24 시(승차):  강남/24 / 23464
# 24 시(하차):  신림/24 / 35434
# 25 시(승차):  시청/25 / 2483
# 25 시(하차):  서울대입구(관악구청)/25 / 5137
# 26 시(승차):  시청/26 / 3082
# 26 시(하차):  홍대입구/26 / 863
# 27 시(승차):  신촌/27 / 94
# 27 시(하차):  신림/27 / 312

# %%
import csv
data = csv.reader(open('201806subway.csv'))
next(data)
next(data)
인원 = []
역이름 = input('무슨 역인가요?')
호선 = input('몇 호선인가요?')

for row in data :
    if(row[1] == 역이름 and row[0] == 호선):
        print(row[1])
        인원 = row[2:]
    
승차 = 인원[::2]
하차 = 인원[1::2]

print(승차)
print(하차)

max_num1 = max(map(int,인원[::2]))
max_num2 = max(map(int,인원[1::2]))
max_num = max(max_num1, max_num2)

import matplotlib.pyplot as plt



plt.rc('font', family='AppleGothic')
# plt.rcParams['axes.unicode_minus'] = False

# plt.rc('font',family='Malgun Gothic')

labels = []
x = []
for i in range(4,28):
    labels.append(str(i)+'시')
    x.append(i)
    
plt.figure(dpi=200)
plt.xticks(x, labels,rotation='vertical')
plt.plot(x,승차,'r', label='승차 인원')
plt.plot(x,하차,'b', label='하차 인원')
plt.ylim(ymax=max_num + 4000)
plt.title(역이름+'('+호선+')')
plt.legend()
plt.savefig('test3.png')
plt.show()
# Out:
# 무슨 역인가요?신도림
# 몇 호선인가요?2호선
# 신도림
# ['3457', '44259', '59777', '150860', '153722', '102636', '73184', '72766', '83987', '90399', '88319', '93801', '102719', '113972', '155685', '104198', '88445', '93834', '77545', '33068', '4428', '54', '18', '7']
# ['27', '6765', '25146', '48487', '127227', '87662', '80112', '78606', '86901', '89175', '81628', '89914', '103764', '128433', '187723', '167899', '98458', '91502', '93132', '72899', '33128', '4260', '317', '211']

# %%
import csv
data = csv.reader(open('201806subway.csv'))
next(data)
next(data)
인원1 = []
인원2 = []
역이름1 = input('첫 번째 역 이름을 입력하세요 : ')
호선1 = input('첫 번째 역은 몇 호선인가요? : ')
역이름2 = input('두 번째 역 이름을 입력하세요 : ')
호선2 = input('첫 번째 역은 몇 호선인가요? : ')

# %matplotlib inline 

for row in data :
    if(row[1] == 역이름1 and row[0] == 호선1): 
        인원1 = row[2:]
    if(row[1] == 역이름2 and row[0] == 호선2):
        인원2 = row[2:]
    
승차1 = 인원1[::2]
하차1 = 인원1[1::2]

승차2 = 인원2[::2]
하차2 = 인원2[1::2]

import matplotlib.pyplot as plt
plt.rc('font', family='AppleGothic')

labels = []
x = []
for i in range(4,28):
    labels.append(str(i)+'시')
    x.append(i)
plt.figure(dpi=300)
    
plt.xticks(x, labels,rotation='vertical')
plt.plot(x,승차1,'r', label=역이름1+'역 승차')
plt.plot(x,승차2,'b', label=역이름2+'역 승차')
plt.ylim(ymax=420000)

plt.xticks(x, labels,rotation='vertical')
plt.plot(x,하차1,'r--', label=역이름1+'역 하차')
plt.plot(x,하차2,'b--', label=역이름2+'역 하차')
plt.ylim(ymax=420000)
plt.title(역이름1+'역 승하차 인원 vs '+역이름2+'역 승하차 인원   # 2018년 6월 기준')
plt.legend()
plt.savefig('test4.png')
plt.show()
# Out:
# 첫 번째 역 이름을 입력하세요 : 신도림
# 첫 번째 역은 몇 호선인가요? : 2호선
# 두 번째 역 이름을 입력하세요 : 잠실
# 첫 번째 역은 몇 호선인가요? : 2호선
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-22bc5b2b4bc2> in <module>()
#      36 plt.xticks(x, labels,rotation='vertical')
#      37 plt.plot(x,승차1,'r', label=역이름1+'역 승차')
# ---> 38 plt.plot(x,승차2,'b', label=역이름2+'역 승차')
#      39 plt.ylim(ymax=420000)
#      40
#
# /Users/greatsong/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# /Users/greatsong/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/greatsong/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# /Users/greatsong/anaconda/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# /Users/greatsong/anaconda/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     383             x, y = index_of(tup[-1])
#     384
# --> 385         x, y = self._xy_from_xy(x, y)
#     386
#     387         if self.command == 'plot':
#
# /Users/greatsong/anaconda/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     242         if x.shape[0] != y.shape[0]:
#     243             raise ValueError("x and y must have same first dimension, but "
# --> 244                              "have shapes {} and {}".format(x.shape, y.shape))
#     245         if x.ndim > 2 or y.ndim > 2:
#     246             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (24,) and (0,)
